# %%
# import the useful libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import pytesseract
import matplotlib.pyplot as plt
# %matplotlib inline

# Read the data set of "Marketing Analysis" in data.
data= pd.read_csv("Marketing_Analysis.csv")

# Printing the data
data
# Out:
# /home/benfild/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# ...

# %%
data.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
# ...

# %%
data = pd.read_csv("Marketing_Analysis.csv", skiprows= 2)
data.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
# Drop the customerId
data.drop('customerid', axis=1, inplace= True)

# extract job & education from "jobedu" column
data['job']= data["jobedu"].apply(lambda x: x.split(",")[0])
data['education']= data["jobedu"].apply(lambda x: x.split(",")[1])

# drop the jobedu col
data.drop('jobedu', axis= 1, inplace= True)

# print the data set
data
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
data.isnull().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %%
data = data[~data.age.isnull()].copy()

data.isnull().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %%
monthMode = data.month.mode()[0]

data.month.fillna(monthMode, inplace= True)

data.isnull().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %%
data = data[~data.response.isnull()].copy()

data.isnull().sum()
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response     0
# job          0
# education    0
# dtype: int64

# %%
data.response.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# Name: response, Length: 45161, dtype: bool

# %% [raw]
# # find the % of each job(
# data.job.value_counts(normalize= True)
# # plot the bar graph of each % of job categories
# data.job.value_counts(normalize= True).plot.barh()
#
# plt.show()

# %%
# for Categorical ordered variable eg education
data.education.value_counts(normalize= True)
# plot the pie chart
data.education.value_counts(normalize= True).plot.pie()
plt.show()

# %%
# for Month ordered data
data.month.value_counts(normalize= True)
# the pie chart plot
data.month.value_counts(normalize= True).plot.pie()
plt.show()

# %%
data.salary.describe()
# Out:
# count     45161.000000
# mean      57004.849317
# std       32087.698810
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
# BIVARIATE ANALYSIS
# plot the scatter of balance and salary column in data
plt.scatter(data.salary, data.balance)
plt.show()

# scatter plot of age and balance
plt.scatter(data.age, data.balance)
plt.show

# %%
sns.pairplot(data, hue= "education")

# %%
sns.pairplot(data, vars=["salary", "balance", "age"], hue= "marital", markers= ["o","s","d"])

# %%
# Numerical and categorical column example salary and response
# groupby finding the mean
data.groupby('response')['salary'].mean()

# %%
# groupby finding the meadian
data.groupby('response')['salary'].median()

# %%
# PLOTBOX the response of yes and no by salary
sns.boxplot(data.response, data.salary)
plt.show()

# %%
# caterogical to caterogical
# convert response "yes"= 1 and "no"=0
data['responseRate'] = np.where(data.response=='yes',1,0)
data.responseRate.value_counts()

# %%
# response rate in marital status categories
data.groupby('marital')['responseRate'].mean().plot.bar()
plt.show()

# %%
# Multivariate analysis btn education, marital and response_rate
# create the pivot table of edu, marital and response
result = pd.pivot_table(data=data, index= 'education', columns= 'marital', values= 'responseRate')
print(result)

# %%
# create the heat map of education vs marital vs responseRate
sns.heatmap(result, annot= True, cmap='RdYlGn', center= 0.117)

# %%
# Out:
# '/home/benfild/Documents/Data science '

# %%
# Out:
# 0
